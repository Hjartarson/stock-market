# %%
import pandas as pd
import seaborn as sb
# %matplotlib inline

# %%
pred = pd.read_csv('pred.csv')

# %%
pred.groupby(['quote','date']).min().style.background_gradient(cmap='RdYlGn',high=0.2, low=0.2)
# Out:
# <style  type="text/css" >
#     #T_99bed5c0_c542_11e7_891d_5ce0c5eee5bdrow0_col0 {
#             background-color:  #feeda1;
#         }    #T_99bed5c0_c542_11e7_891d_5ce0c5eee5bdrow0_col1 {
#             background-color:  #fdb163;
#         }    #T_99bed5c0_c542_11e7_891d_5ce0c5eee5bdrow0_col2 {
#             background-color:  #fff1a8;
#         }    #T_99bed5c0_c542_11e7_891d_5ce0c5eee5bdrow0_col3 {
#             background-color:  #d5ed88;
#         }    #T_99bed5c0_c542_11e7_891d_5ce0c5eee5bdrow0_col4 {
#             background-color:  #f88c51;
#         }    #T_99bed5c0_c542_11e7_891d_5ce0c5eee5bdrow0_col5 {
#             background-color:  #82c966;
#         }    #T_99bed5c0_c542_11e7_891d_5ce0c5eee5bdrow0_col6 {
#             background-color:  #96d268;
#         }    #T_99bed5c0_c542_11e7_891d_5ce0c5eee5bdrow0_col7 {
#             background-color:  #5ab760;
#         }    #T_99bed5c0_c542_11e7_891d_5ce0c5eee5bdrow0_col8 {
#             background-color:  #cbe982;
# ...
