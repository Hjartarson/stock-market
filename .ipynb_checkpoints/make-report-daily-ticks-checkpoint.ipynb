# %%
import matplotlib.pyplot as plt
from cycler import cycler

tableau20 = [(31, 119, 180), (174, 199, 232), (255, 127, 14), (255, 187, 120),    
             (44, 160, 44), (152, 223, 138), (214, 39, 40), (255, 152, 150),    
             (148, 103, 189), (197, 176, 213), (140, 86, 75), (196, 156, 148),    
             (227, 119, 194), (247, 182, 210), (127, 127, 127), (199, 199, 199),    
             (188, 189, 34), (219, 219, 141), (23, 190, 207), (158, 218, 229)] 
for i in range(len(tableau20)):
    r, g, b = tableau20[i]    
    tableau20[i] = (r / 255., g / 255., b / 255.)
    

plt.rc('figure', figsize=(14, 8),titlesize=16)
plt.rc('legend', frameon=True,fancybox=True,fontsize=14)
plt.rc('xtick', labelsize=12)
plt.rc('ytick', labelsize=12)
plt.rc('grid', linestyle="--", color='grey',alpha = 0.2)
plt.rc('font', size=14, family='sans-serif',style='normal',weight='normal')
plt.rc('axes', labelsize=14, titlesize=14,
       titleweight='bold',prop_cycle=(cycler('color',tableau20)))

# %%
import pandas as pd
import numpy as np
import datetime
import os
# %matplotlib inline

import matplotlib as mpl
#import seaborn as sns

# %%
df = pd.read_pickle(os.path.join('data','quote=FING-BSSAB-B&start=2016-10-03&end=2017-10-02&interval=1440min.pkl'))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 7 columns):
# datetime    506 non-null datetime64[ns]
# stock       506 non-null object
# open        506 non-null float64
# high        506 non-null float64
# low         506 non-null float64
# close       506 non-null float64
# volume      506 non-null float64
# dtypes: datetime64[ns](1), float64(5), object(1)
# memory usage: 27.8+ KB

# %%
df_stock = df.groupby(['datetime','stock']).sum().unstack()
stocks = df_stock['close'].columns
df_stock['close'].plot(grid=True)
df_stock.head()
# Out:
#                        open           high           low          close  \
# stock                FING-B SSAB-B  FING-B SSAB-B FING-B SSAB-B  FING-B
# datetime
# 2016-10-03 17:30:00  101.00  20.90  101.50  21.47  99.30  20.85   99.80
# 2016-10-04 17:30:00  100.00  21.30  100.90  21.82  99.00  21.30   99.80
# 2016-10-05 17:30:00  100.20  21.68  101.00  21.84  99.25  21.47  100.20
# 2016-10-06 17:30:00   99.75  21.85   99.85  21.94  95.25  21.56   96.25
# 2016-10-07 17:30:00   97.00  21.80   97.20  22.39  94.10  21.78   95.40
#
#                                 volume
# stock               SSAB-B      FING-B     SSAB-B
# datetime
# 2016-10-03 17:30:00  21.32   2840234.0  4630179.0
# 2016-10-04 17:30:00  21.75   3377179.0  4041791.0
# 2016-10-05 17:30:00  21.80   4156429.0  3391308.0
# 2016-10-06 17:30:00  21.68  11570839.0  2261553.0
# 2016-10-07 17:30:00  22.20   6092416.0  6582477.0

# %%
# ADD MEASURES
# DAY
df_stock = df_stock.join(df_stock[['close']].div(df_stock['open'])
                         .sub(1).mul(100).rename(columns={'close':'pct_open_close'}))
df_stock = df_stock.join(df_stock[['high']].div(df_stock['low'])
                         .sub(1).mul(100).rename(columns={'high':'pct_low_high'}))
df_stock = df_stock.join(df_stock[['high']].div(df_stock['open'])
                         .sub(1).mul(100).rename(columns={'high':'pct_open_high'}))
# SHIFT SINGLE
df_stock = df_stock.join(df_stock[['open']].div(df_stock['close'].shift(periods=1))
                         .sub(1).mul(100).rename(columns={'open':'pct_close_open'}))
df_stock = df_stock.join(df_stock[['close']].div(df_stock['close'].shift(periods=1))
                         .sub(1).mul(100).rename(columns={'close':'pct_close_close'}))

for days in np.arange(1,11):
    df_stock = df_stock.join(df_stock[['close']].div(df_stock['open'].shift(periods=days))
                             .sub(1).mul(100).rename(columns={'close':'pct_open_close_days_'+str(days)}))
    
#SHIFT BOTH BACK IN TIME (FOR CORR Y MEASURE)
df_stock = df_stock.join(df_stock[['close']].shift(periods=-1).div(df_stock['close'].shift(periods=-2))
                         .sub(1).mul(100).rename(columns={'close':'pct_close_close_next_day'}))

df_stock.head()
# Out:
#                        open           high           low          close  \
# stock                FING-B SSAB-B  FING-B SSAB-B FING-B SSAB-B  FING-B
# datetime
# 2016-10-03 17:30:00  101.00  20.90  101.50  21.47  99.30  20.85   99.80
# 2016-10-04 17:30:00  100.00  21.30  100.90  21.82  99.00  21.30   99.80
# 2016-10-05 17:30:00  100.20  21.68  101.00  21.84  99.25  21.47  100.20
# 2016-10-06 17:30:00   99.75  21.85   99.85  21.94  95.25  21.56   96.25
# 2016-10-07 17:30:00   97.00  21.80   97.20  22.39  94.10  21.78   95.40
#
#                                 volume               ...     \
# stock               SSAB-B      FING-B     SSAB-B    ...
# datetime                                             ...
# 2016-10-03 17:30:00  21.32   2840234.0  4630179.0    ...
# 2016-10-04 17:30:00  21.75   3377179.0  4041791.0    ...
# 2016-10-05 17:30:00  21.80   4156429.0  3391308.0    ...
# 2016-10-06 17:30:00  21.68  11570839.0  2261553.0    ...
# 2016-10-07 17:30:00  22.20   6092416.0  6582477.0    ...
#
#                     pct_open_close_days_7        pct_open_close_days_8         \
# stock                              FING-B SSAB-B                FING-B SSAB-B
# datetime
# 2016-10-03 17:30:00                   NaN    NaN                   NaN    NaN
# 2016-10-04 17:30:00                   NaN    NaN                   NaN    NaN
# 2016-10-05 17:30:00                   NaN    NaN                   NaN    NaN
# 2016-10-06 17:30:00                   NaN    NaN                   NaN    NaN
# 2016-10-07 17:30:00                   NaN    NaN                   NaN    NaN
#
#                     pct_open_close_days_9        pct_open_close_days_10  \
# stock                              FING-B SSAB-B                 FING-B
# datetime
# 2016-10-03 17:30:00                   NaN    NaN                    NaN
# 2016-10-04 17:30:00                   NaN    NaN                    NaN
# 2016-10-05 17:30:00                   NaN    NaN                    NaN
# 2016-10-06 17:30:00                   NaN    NaN                    NaN
# 2016-10-07 17:30:00                   NaN    NaN                    NaN
#
#                            pct_close_close_next_day
# stock               SSAB-B                   FING-B    SSAB-B
# datetime
# 2016-10-03 17:30:00    NaN                -0.399202 -0.229358
# 2016-10-04 17:30:00    NaN                 4.103896  0.553506
# 2016-10-05 17:30:00    NaN                 0.890985 -2.342342
# 2016-10-06 17:30:00    NaN                -3.733602 -1.682905
# 2016-10-07 17:30:00    NaN                 4.646251  0.983900
#
# [5 rows x 42 columns]

# %%
df_stock_swap = df_stock.swaplevel(axis=1)
df_stock_swap.head()
# Out:
# stock                FING-B SSAB-B  FING-B SSAB-B FING-B SSAB-B  FING-B  \
#                        open   open    high   high    low    low   close
# datetime
# 2016-10-03 17:30:00  101.00  20.90  101.50  21.47  99.30  20.85   99.80
# 2016-10-04 17:30:00  100.00  21.30  100.90  21.82  99.00  21.30   99.80
# 2016-10-05 17:30:00  100.20  21.68  101.00  21.84  99.25  21.47  100.20
# 2016-10-06 17:30:00   99.75  21.85   99.85  21.94  95.25  21.56   96.25
# 2016-10-07 17:30:00   97.00  21.80   97.20  22.39  94.10  21.78   95.40
#
# stock               SSAB-B      FING-B     SSAB-B           ...             \
#                      close      volume     volume           ...
# datetime                                                    ...
# 2016-10-03 17:30:00  21.32   2840234.0  4630179.0           ...
# 2016-10-04 17:30:00  21.75   3377179.0  4041791.0           ...
# 2016-10-05 17:30:00  21.80   4156429.0  3391308.0           ...
# 2016-10-06 17:30:00  21.68  11570839.0  2261553.0           ...
# 2016-10-07 17:30:00  22.20   6092416.0  6582477.0           ...
#
# stock                              FING-B                SSAB-B  \
#                     pct_open_close_days_7 pct_open_close_days_7
# datetime
# 2016-10-03 17:30:00                   NaN                   NaN
# 2016-10-04 17:30:00                   NaN                   NaN
# 2016-10-05 17:30:00                   NaN                   NaN
# 2016-10-06 17:30:00                   NaN                   NaN
# 2016-10-07 17:30:00                   NaN                   NaN
#
# stock                              FING-B                SSAB-B  \
#                     pct_open_close_days_8 pct_open_close_days_8
# datetime
# 2016-10-03 17:30:00                   NaN                   NaN
# 2016-10-04 17:30:00                   NaN                   NaN
# 2016-10-05 17:30:00                   NaN                   NaN
# 2016-10-06 17:30:00                   NaN                   NaN
# 2016-10-07 17:30:00                   NaN                   NaN
#
# stock                              FING-B                SSAB-B  \
#                     pct_open_close_days_9 pct_open_close_days_9
# datetime
# 2016-10-03 17:30:00                   NaN                   NaN
# 2016-10-04 17:30:00                   NaN                   NaN
# 2016-10-05 17:30:00                   NaN                   NaN
# 2016-10-06 17:30:00                   NaN                   NaN
# 2016-10-07 17:30:00                   NaN                   NaN
#
# stock                               FING-B                 SSAB-B  \
#                     pct_open_close_days_10 pct_open_close_days_10
# datetime
# 2016-10-03 17:30:00                    NaN                    NaN
# 2016-10-04 17:30:00                    NaN                    NaN
# 2016-10-05 17:30:00                    NaN                    NaN
# 2016-10-06 17:30:00                    NaN                    NaN
# 2016-10-07 17:30:00                    NaN                    NaN
#
# stock                                 FING-B                   SSAB-B
#                     pct_close_close_next_day pct_close_close_next_day
# datetime
# 2016-10-03 17:30:00                -0.399202                -0.229358
# 2016-10-04 17:30:00                 4.103896                 0.553506
# 2016-10-05 17:30:00                 0.890985                -2.342342
# 2016-10-06 17:30:00                -3.733602                -1.682905
# 2016-10-07 17:30:00                 4.646251                 0.983900
#
# [5 rows x 42 columns]

# %%
#CHECK CORRELATION BETWEEN MEASURES
import seaborn as sns

corr_var = [x for x in np.unique(df_stock.columns.get_level_values(level=0)) if 'pct' in x]

for stock in stocks:
    f, ax = plt.subplots(1,1)
    corr = df_stock_swap[stock][corr_var].corr()
    sns.heatmap(corr,square=True, ax=ax)
    ax.set_title(stock)

# %%
#CHECK CORRELATION BETWEEN MEASURES AND STOCKS!
import seaborn as sns

f, ax = plt.subplots(1,1)

corr_var = [x for x in np.unique(df_stock.columns.get_level_values(level=0)) if 'pct' in x]
print(corr_var)
corr = df_stock[corr_var].corr()
sns.heatmap(corr,square=True, ax=ax)
# Out:
# ['pct_close_close', 'pct_close_close_next_day', 'pct_close_open', 'pct_low_high', 'pct_open_close', 'pct_open_close_days_1', 'pct_open_close_days_10', 'pct_open_close_days_2', 'pct_open_close_days_3', 'pct_open_close_days_4', 'pct_open_close_days_5', 'pct_open_close_days_6', 'pct_open_close_days_7', 'pct_open_close_days_8', 'pct_open_close_days_9', 'pct_open_high']

# %% [markdown]
# ### What happened x days after a decline?

# %%
# DAY
x_days = 1
pct_change = -2
df_days = []
for x_days in [1,2,3,4,5,6]:
    df_temp = (
        df_stock['pct_close_close'][(df_stock['pct_close_close']<pct_change).shift(x_days).replace(np.nan,False)]
        .stack().rename(str(x_days)).reset_index()[str(x_days)]
    )
    df_days.append(df_temp)
df_days = pd.concat(df_days,axis=1)
df_days.plot(kind='box',grid=True)

# %%
# STOCK
x_days = 3
df_stock['pct_close_close'][(df_stock['pct_close_close']<pct_change).shift(x_days).replace(np.nan,False)].plot(kind='box',grid=True)

# %%
df_stock_swap = df_stock.swaplevel(axis=1)

# CLose price change dependancy
f, ax = plt.subplots(1,1)
x = 'pct_close_open'
y = 'pct_open_close'
colors = ['blue','red']
for nr,stock in enumerate(stocks):
    print(nr)
    df_sel = df_stock_swap[stock]
    df_sel.plot(ax=ax,kind='scatter',x=x,y=y,grid=True,s=20,color=colors[nr],edgecolor='black',title=x+' | '+y,legend=True)
ax.legend(stocks)
ax.axhline(0,ls = '--',color='red')
ax.axvline(0,ls = '--',color='red')
# Out:
# 0
# 1
