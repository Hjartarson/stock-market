# %%
import urllib.request
import json
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
soup.find('h3', class_='base-search-card__title').text
# Out:
# '\n            \n        Data Scientist\n      \n          '

# %%
html_site = 'https://www.linkedin.com/jobs/search/?currentJobId=3436432905&geoId=105117694&keywords=data%20scientist&location=Sweden&refresh=true&spellCorrectionEnabled=false'

html = requests.get(html_site).content
soup = BeautifulSoup(html, 'html.parser')

soup


#job_title = soup.find('h3', class_='base-search-card__title').textprint(job_title)
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta content="d_jobs_guest_search" name="pageKey"/>
# <meta content="urlType=jserp_custom;emptyResult=false" name="linkedin:pageTag"/>
# <meta content="en_US" name="locale"/>
# <meta data-app-version="2.0.1247" data-browser-id="9ed0f360-0578-472b-8334-a697d4c2104f" data-call-tree-id="AAXzdlvBRaNOdVL0rOAR5w==" data-disable-jsbeacon-pagekey-suffix="false" data-enable-page-view-heartbeat-tracking="" data-member-id="0" data-multiproduct-name="jobs-guest-frontend" data-page-instance="urn:li:page:d_jobs_guest_search;DwkxpFg/TJmPrknMwOml1w==" data-service-name="jobs-guest-frontend" id="config"/>
# <link href="https://se.linkedin.com/jobs/data-scientist-jobs" rel="canonical"/>
# <!-- --><!-- -->
# <!-- -->
# <!-- -->
# <!-- -->
# <!-- -->
# <link href="https://static.licdn.com/aero-v1/sc/h/al2o9zrvru7aqj8e1x2rzsrca" rel="icon"/>
# <script>
# ...

# %%
html = requests.get('https://tingent.se/jobs').content
soup = BeautifulSoup(html, 'html.parser')

# TINGENT
data = json.loads(soup.find('script', type='application/json').text)
df_ting = pd.DataFrame(data['props']['pageProps']['jobsData'])

for i in df_ting.loc[0]:
    print(i)

df_ting.head(1).T

# %%
# KEYMAN
html = requests.get('https://keyman.se/uppdrag/').content
soup = BeautifulSoup(html, 'html.parser')

for a in soup.find_all('div', 
     class_ = 'post-content-wrap'):
    print(a)
