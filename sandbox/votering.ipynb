# %%
import pandas as pd

# %%
df = pd.read_csv('votering-202223.csv')
df.head()
# Out:
#       year   e1                                    e2  e3  \
# 0  2022/23  CU2  0862564A-E7C4-47AB-A43E-D2F42B3D54B2   2
# 1  2022/23  CU2  0862564A-E7C4-47AB-A43E-D2F42B3D54B2   2
# 2  2022/23  CU2  0862564A-E7C4-47AB-A43E-D2F42B3D54B2   2
# 3  2022/23  CU2  0862564A-E7C4-47AB-A43E-D2F42B3D54B2   2
# 4  2022/23  CU2  0862564A-E7C4-47AB-A43E-D2F42B3D54B2   2
#
#                   namn            e4 party               area         vote  \
# 0        Julia Kronlid  638497389621    SD     Stockholms län  Frånvarande
# 1       Helena Bouveng  729710260118     M     Jönköpings län  Frånvarande
# 2      Mattias Jonsson  499755198526     S   Göteborgs kommun           Ja
# 3  Jessica Rosencrantz  992420223820     M  Stockholms kommun           Ja
# 4       Jimmie Åkesson   51207517226    SD     Jönköpings län  Frånvarande
#
#         type  e5  gender  birth_year        date
# 0  sakfrågan   2  kvinna        1980  2022-11-24
# 1  sakfrågan  10  kvinna        1962  2022-11-24
# ...

# %%
df.groupby(['e2', 'party', 'vote'])['vote'].count().unstack(level=1).head(20)
# Out:
# party                                                C    KD     L     M  \
# e2                                   vote
# 0862564A-E7C4-47AB-A43E-D2F42B3D54B2 Frånvarande   4.0   2.0   3.0  10.0
#                                      Ja           20.0  17.0  13.0  58.0
#                                      Nej           NaN   NaN   NaN   NaN
# 0E7BC721-232A-495A-B305-FC99575F83ED Frånvarande   3.0   2.0   3.0  11.0
#                                      Ja            NaN  17.0  13.0  57.0
#                                      Nej          21.0   NaN   NaN   NaN
# 105A8CB7-913F-43DA-9369-3122FBF35EA3 Frånvarande   4.0   3.0   3.0   9.0
#                                      Ja           20.0  16.0  13.0  59.0
#                                      Nej           NaN   NaN   NaN   NaN
# 1459843C-F3F9-43D5-933C-759BE764543B Frånvarande   3.0   2.0   2.0   8.0
#                                      Ja           21.0  17.0  14.0  60.0
# ...
