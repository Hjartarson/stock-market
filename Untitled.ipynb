# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sys
import os
import matplotlib as mpl

import os
import pandas as pd

import matplotlib.pyplot as plt

# %%
df = pd.read_csv('ska_years.csv', skiprows=1, delimiter=';')
df['Date'] = pd.to_datetime(df['Date'])
df = df.sort_values(by='Date')
df['Closing price'] = df['Closing price'].str.replace(',','.').astype('float')
df = df.set_index('Date')
df#['Handle'] = df['Price'].mul(df['Volume'])
# Out:
#                Bid     Ask Opening price High price Low price  Closing price  \
# Date
# 2020-10-13  192,15  192,25        194,80     196,35    191,65         191.65
# 2020-10-14  191,90  192,00        191,90     193,00    191,25         191.75
# 2020-10-15  186,10  186,20        189,60     189,60    185,45         185.85
# 2020-10-16  188,20  188,30        187,45     188,85    185,25         187.70
# 2020-10-19  189,80  189,95        187,80     191,00    187,70         190.00
# ...            ...     ...           ...        ...       ...            ...
# 2021-10-06  213,60  213,80        216,40     216,70    212,00         214.20
# 2021-10-07  219,70  219,80        217,00     220,00    216,60         219.80
# 2021-10-08  217,20  217,40        219,80     219,80    215,50         217.10
# 2021-10-11  215,80  216,00        216,20     217,00    214,80         216.30
# 2021-10-12  218,20  218,40        213,60     218,30    212,80         218.30
#
# ...

# %%
#df['Closing price'] = df['Closing price'].str.replace(',','.').astype('float')
f, ax = plt.subplots(figsize = (14,10))
df['Closing price'].plot(ax=ax)
df['Closing price'].rolling(10).mean().plot(ax=ax, c='red')
df['Closing price'].rolling(20).mean().plot(ax=ax)
df['Trades'].plot(ax=ax, secondary_y = True)
# Out:
# <AxesSubplot:label='3f684931-6d99-438d-b265-44d89266261a'>

# %%
df['pct_change'] = df['Closing price'].pct_change()
df.head()
# Out:
#                Bid     Ask Opening price High price Low price  Closing price  \
# Date
# 2020-10-13  192,15  192,25        194,80     196,35    191,65         191.65
# 2020-10-14  191,90  192,00        191,90     193,00    191,25         191.75
# 2020-10-15  186,10  186,20        189,60     189,60    185,45         185.85
# 2020-10-16  188,20  188,30        187,45     188,85    185,25         187.70
# 2020-10-19  189,80  189,95        187,80     191,00    187,70         190.00
#
#            Average price  Total volume      Turnover  Trades  Unnamed: 11  \
# Date
# 2020-10-13        192,66        694352  133779042,73    2791          NaN
# 2020-10-14       191,897        626000  120127422,56    2564          NaN
# 2020-10-15       186,475       1105482  206151091,06    4777          NaN
# 2020-10-16       187,299       1105979  207138362,57    3950          NaN
# 2020-10-19       189,516        807979   153060030,8    4513          NaN
#
#             pct_change
# Date
# ...

# %%
f, ax = plt.subplots(figsize = (14,10))

df['pct_change'].rolling(10).mean().plot(ax=ax, ls='--')
df['pct_change'].rolling(10).median().plot(ax=ax)
df['Closing price'].plot(ax=ax, secondary_y = True)
ax.axhline(0, c='r', ls='--')
